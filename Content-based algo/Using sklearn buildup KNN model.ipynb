# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelBinarizer, MultiLabelBinarizer, MinMaxScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
from sklearn.decomposition import PCA

pd.set_option("max_colwidth", None)

# %%
from jikanpy import Jikan
jikan = Jikan()

mushishi = jikan.anime(457)
mushishi_with_eps = jikan.anime(457, extension='episodes')

search_result = jikan.search('anime', 'Mushishi', page=2)

winter_2018_anime = jikan.season(year=2018, season='winter')

archive = jikan.season_archive()

# %%
print(jikan.user(username='Xinil', request='animelist')['anime'][0]['score'])
# Out:
# 9

# %%
usecols = ["MAL_ID", "Name", "Score", "Genres", "Type", "Episodes", "Premiered",
           "Studios", "Source", "Rating", "Members"]

anime_data=pd.read_csv('anime.csv',usecols=usecols)

anime_data.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                                 Genres   Type Episodes  \
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26
# 1                Action, Drama, Mystery, Sci-Fi, Space  Movie        1
# 2    Action, Sci-Fi, Adventure, Comedy, Drama, Shounen     TV       26
# 3  Action, Mystery, Police, Supernatural, Drama, Magic     TV       26
# 4            Adventure, Fantasy, Shounen, Supernatural     TV       52
#
#      Premiered         Studios    Source                          Rating  \
# 0  Spring 1998         Sunrise  Original  R - 17+ (violence & profanity)
# 1      Unknown           Bones  Original  R - 17+ (violence & profanity)
# 2  Spring 1998        Madhouse     Manga       PG-13 - Teens 13 or older
# 3  Summer 2002         Sunrise  Original       PG-13 - Teens 13 or older
# 4    Fall 2004  Toei Animation     Manga                   PG - Children
#
#    Members
# 0  1251960
# 1   273145
# 2   558913
# 3    94683
# 4    13224

# %%
def process_multilabel(series):
    series = series.split(",")
    if "Unknown" in series:
        series.remove("Unknown")
    return series

anime_data["Genres"] = anime_data["Genres"].map(process_multilabel)
anime_data["Studios"] = anime_data["Studios"].map(process_multilabel)
anime_data["Score"] = anime_data["Score"].replace("Unknown", 0).astype(float)
anime_data["Episodes"] = anime_data["Episodes"].replace("Unknown", 0).astype(int)

# %%
def preprocessing_category(df, column, is_multilabel=False):
    # Binarise labels
    lb = LabelBinarizer()
    if is_multilabel:
        lb = MultiLabelBinarizer()
        
    expandedLabelData = lb.fit_transform(df[column])
    labelClasses = lb.classes_

    # Create a pandas.DataFrame from our output
    category_df = pd.DataFrame(expandedLabelData, columns=labelClasses)
    del df[column]
    return pd.concat([df, category_df], axis=1)

anime_metadata = anime_data.copy()
anime_metadata = preprocessing_category(anime_metadata, "Type")
anime_metadata = preprocessing_category(anime_metadata, "Premiered")
anime_metadata = preprocessing_category(anime_metadata, "Studios", is_multilabel=True)
anime_metadata = preprocessing_category(anime_metadata, "Source")
anime_metadata = preprocessing_category(anime_metadata, "Rating")

Genders = anime_metadata["Genres"]
ID_NAME = anime_metadata[["MAL_ID", "Name"]]

del anime_metadata["Genres"]
del anime_metadata["MAL_ID"]
del anime_metadata["Name"]
del anime_metadata["Unknown"]

anime_metadata[["Score", "Episodes", "Members"]] = MinMaxScaler().fit_transform(anime_metadata[["Score", "Episodes", "Members"]])
anime_metadata = anime_metadata.values

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfv = TfidfVectorizer(min_df=3,  max_features=None, 
            strip_accents='unicode', analyzer='word',token_pattern=r'\w{1,}',
            ngram_range=(1, 3),
            stop_words = 'english')

# Filling NaNs with empty string
genres_original = anime_data['Genres'].fillna('').astype(str)
genres_vector_tf_idf = tfv.fit_transform(genres_original)

genres_vector_one_hot = preprocessing_category(pd.DataFrame(Genders), "Genres", True).values

# %%
def get_recommended(vector, query_index, n_neighbors=10):
    model_knn = NearestNeighbors(metric='cosine', n_neighbors=n_neighbors)
    model_knn.fit(csr_matrix(vector))

    distances, indices = model_knn.kneighbors(vector[query_index,:].reshape(1, -1), n_neighbors = n_neighbors)
    result = []
    for i in range(0, len(distances.flatten())):
        index = indices.flatten()[i]
        if index == query_index:
            continue
        result.append(anime_data.iloc[index])
        
    return pd.DataFrame(result)

# %%
query_index1 = ID_NAME[ID_NAME.MAL_ID == 1].index[0]
anime_data.iloc[[query_index1]]
# Out:
#    MAL_ID          Name  Score  \
# 0       1  Cowboy Bebop   8.78
#
#                                                    Genres Type  Episodes  \
# 0  [Action,  Adventure,  Comedy,  Drama,  Sci-Fi,  Space]   TV        26
#
#      Premiered    Studios    Source                          Rating  Members
# 0  Spring 1998  [Sunrise]  Original  R - 17+ (violence & profanity)  1251960

# %%
get_recommended(anime_metadata, query_index1, 5)
# Out:
#        MAL_ID                                      Name  Score  \
# 2656     2904        Code Geass: Hangyaku no Lelouch R2   8.91
# 1431     1575           Code Geass: Hangyaku no Lelouch   8.72
# 2368     2581                     Mobile Suit Gundam 00   8.14
# 10880   31251  Mobile Suit Gundam: Iron-Blooded Orphans   8.02
#
#                                                                     Genres  \
# 2656            [Action,  Military,  Sci-Fi,  Super Power,  Drama,  Mecha]
# 1431   [Action,  Military,  Sci-Fi,  Super Power,  Drama,  Mecha,  School]
# 2368                  [Action,  Military,  Sci-Fi,  Space,  Drama,  Mecha]
# 10880                            [Action,  Drama,  Mecha,  Sci-Fi,  Space]
#
#       Type  Episodes    Premiered    Studios    Source  \
# 2656    TV        25  Spring 2008  [Sunrise]  Original
# 1431    TV        25    Fall 2006  [Sunrise]  Original
# 2368    TV        25    Fall 2007  [Sunrise]  Original
# 10880   TV        25    Fall 2015  [Sunrise]  Original
#
#                                Rating  Members
# 2656   R - 17+ (violence & profanity)  1268320
# 1431   R - 17+ (violence & profanity)  1583882
# 2368   R - 17+ (violence & profanity)   183997
# 10880  R - 17+ (violence & profanity)   165393

# %%
query_index2 = ID_NAME[ID_NAME.MAL_ID == 7].index[0]
anime_data.iloc[[query_index2]]
# Out:
#    MAL_ID                Name  Score  \
# 3       7  Witch Hunter Robin   7.27
#
#                                                        Genres Type  Episodes  \
# 3  [Action,  Mystery,  Police,  Supernatural,  Drama,  Magic]   TV        26
#
#      Premiered    Studios    Source                     Rating  Members
# 3  Summer 2002  [Sunrise]  Original  PG-13 - Teens 13 or older    94683

# %%
get_recommended(anime_metadata, query_index2, 5)
# Out:
#       MAL_ID                     Name  Score  \
# 663      721            Princess Tutu   8.15
# 5988    9941            Tiger & Bunny   7.94
# 64        85  Mobile Suit Zeta Gundam   7.92
# 59        80       Mobile Suit Gundam   7.78
#
#                                                       Genres Type  Episodes  \
# 663   [Comedy,  Drama,  Fantasy,  Magic,  Mystery,  Romance]   TV        38
# 5988               [Action,  Mystery,  Comedy,  Super Power]   TV        25
# 64     [Military,  Sci-Fi,  Space,  Drama,  Romance,  Mecha]   TV        50
# 59              [Action,  Military,  Sci-Fi,  Space,  Mecha]   TV        43
#
#         Premiered           Studios    Source                     Rating  \
# 663   Summer 2002  [Hal Film Maker]  Original  PG-13 - Teens 13 or older
# 5988  Spring 2011         [Sunrise]  Original  PG-13 - Teens 13 or older
# 64    Spring 1985         [Sunrise]  Original  PG-13 - Teens 13 or older
# 59    Spring 1979         [Sunrise]  Original  PG-13 - Teens 13 or older
#
#       Members
# 663    129950
# 5988   182872
# 64      53822
# 59      97216

# %%
query_index3 = ID_NAME[ID_NAME.MAL_ID == 100].index[0]
anime_data.iloc[[query_index3]]
# Out:
#     MAL_ID                                  Name  Score  \
# 79     100  Shin Shirayuki-hime Densetsu Prétear    7.2
#
#                                                                  Genres Type  \
# 79  [Comedy,  Drama,  Fantasy,  Magic,  Romance,  Shoujo,  Super Power]   TV
#
#     Episodes    Premiered           Studios Source                     Rating  \
# 79        13  Spring 2001  [Hal Film Maker]  Manga  PG-13 - Teens 13 or older
#
#     Members
# 79    53508

# %%
get_recommended(anime_metadata, query_index3, 5)
# Out:
#       MAL_ID                             Name  Score  \
# 3793    4722                       Skip Beat!   8.13
# 229      253  Jungle wa Itsumo Hare nochi Guu   7.84
# 1568    1728         Super GALS! Kotobuki Ran   7.42
# 1834    2014  Taiho Shichau zo: Second Season   7.41
#
#                                     Genres Type  Episodes    Premiered  \
# 3793   [Comedy,  Drama,  Romance,  Shoujo]   TV        25    Fall 2008
# 229      [Slice of Life,  Comedy,  School]   TV        26  Spring 2001
# 1568     [Comedy,  Slice of Life,  Shoujo]   TV        52  Spring 2001
# 1834  [Action,  Comedy,  Police,  Shounen]   TV        26  Spring 2001
#
#                   Studios Source                     Rating  Members
# 3793     [Hal Film Maker]  Manga  PG-13 - Teens 13 or older   219475
# 229   [Shin-Ei Animation]  Manga  PG-13 - Teens 13 or older    29653
# 1568     [Studio Pierrot]  Manga  PG-13 - Teens 13 or older    15854
# 1834        [Studio Deen]  Manga  PG-13 - Teens 13 or older     8412

# %%
query_index3 = ID_NAME[ID_NAME.Name=='Boku no Pico'].index[0]
print(anime_data.iloc[[query_index3]])
get_recommended(anime_metadata, query_index3, 5)
# Out:
#       MAL_ID          Name  Score           Genres Type  Episodes Premiered  \
# 1490    1639  Boku no Pico   4.37  [Hentai,  Yaoi]  OVA         1   Unknown
#
#                      Studios    Source       Rating  Members
# 1490  [Sugar Boy,  Blue Cat]  Original  Rx - Hentai   137560
#       MAL_ID                               Name  Score           Genres Type  \
# 4113    5391                      Pico to Chico   4.49  [Hentai,  Yaoi]  OVA
# 3862    4866                Pico x CoCo x Chico   4.46  [Hentai,  Yaoi]  OVA
# 2728    2990                  Mini Skirt Gakuen   4.54         [Hentai]  OVA
# 3114    3541  Kouin Tenshi: Haitoku no Lycéenne   4.91         [Hentai]  OVA
#
#       Episodes Premiered                 Studios    Source       Rating  \
# 4113         1   Unknown  [Sugar Boy,  Blue Cat]  Original  Rx - Hentai
# 3862         1   Unknown  [Sugar Boy,  Blue Cat]  Original  Rx - Hentai
# 2728         1   Unknown                      []  Original  Rx - Hentai
# 3114         1   Unknown                      []  Original  Rx - Hentai
#
#       Members
# 4113    58893
# 3862    55155
# 2728     1270
# 3114     1106
